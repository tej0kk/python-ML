# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('ANTENA 1 satuan DBM.csv')

# %%
data1
# Out:
#         Unnamed: 0                                  Unnamed: 1 Unnamed: 2  \
# 0              NaN                                         NaN        NaN
# 1   Percobaan ant1                                         NaN        NaN
# 2              NaN                      Decibel miliWatt (dBm)        NaN
# 3               No                                      R1ant0     R2ant0
# 4                1                                       35,08      32,12
# 5                2                                       25,18      31,10
# 6                3                                       35,42      31,54
# 7                4                                       35,46      31,53
# 8                5                                       24,79      31,29
# 9                6                                       34,99      21,58
# 10               7                                       35,15      31,83
# 11               8                                       35,09      31,51
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  27 non-null     object
#  1   Unnamed: 1  27 non-null     object
#  2   Unnamed: 2  26 non-null     object
#  3   Unnamed: 3  26 non-null     object
#  4   Unnamed: 4  26 non-null     object
#  5   Unnamed: 5  26 non-null     object
# dtypes: object(6)
# memory usage: 1.5+ KB

# %%
data1.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# count          27         27         26         26         26         26
# unique         27         24         21         24         20         24
# top            22      35,08      31,62      34,82      35,36      30,31
# freq            1          3          2          2          3          2
